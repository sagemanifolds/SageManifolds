# %%
from sage.manifolds.manifold import TopologicalManifold
class_graph(TopologicalManifold)
# Out:
# Digraph on 9 vertices

# %%
from sage.manifolds.submanifold.pseudo_riemannian_submanifold import PseudoRiemannianSubmanifold
class_graph(PseudoRiemannianSubmanifold)
# Out:
# Digraph on 14 vertices
